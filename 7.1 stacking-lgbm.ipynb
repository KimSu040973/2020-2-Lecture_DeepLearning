# %% [markdown]
# # lgbm-stacking 데모
# * 알고리즘 rf, lgbm, lr 적용한 앙상블 기법  stacking 적용
# * 개별 모델이 예측한 데이터를 다시 training set 으로 사용해서 학습
#
# ## 라이브러리 import 및 설정

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
import lightgbm as lgb
from matplotlib import pyplot as plt
from matplotlib import rcParams
import numpy as np
from pathlib import Path
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score


import seaborn as sns
import warnings
rcParams['figure.figsize'] = (16, 8)       #그림 사이즈 지정
plt.style.use('fivethirtyeight')           #그림 기본 스타일
pd.set_option('max_columns', 100)          #칼럼 100개 허용
pd.set_option("display.precision", 4)      #소수점 4자리허용
warnings.simplefilter('ignore')            #경고분 무시

# %% [markdown]
# ## 학습데이터 로드

# %%
feature_file = 'C:\\Users\\USER\\Desktop\\Dataset\\DataInput\\feature.csv'
sample_file  = 'C:\\Users\\USER\\Desktop\\Dataset\\DataInput\\sample_submission.csv'
tst_file     = 'C:\\Users\\USER\\Desktop\\Dataset\\DataInput\\testset.csv'
trn_file     = 'C:\\Users\\USER\\Desktop\\Dataset\\DataInput\\trainset.csv'
val_dir      = Path('C:\\Users\\USER\\Desktop\\Dataset\\val')
tst_dir      = Path('C:\\Users\\USER\\Desktop\\Dataset\\tst')

# %% [markdown]
# ## Stacking Feature 생성

# %%
model_names = ['lrcvPolyfeature', 'rfcvFeature', 'lgbmcvFeature']
trn = []
tst = []
feature_names = []
for model in model_names:
    trn.append(pd.read_csv(val_dir / f'{model}.val.csv', delimiter=',',header=None))
    tst.append(pd.read_csv(tst_dir / f'{model}.tst.csv', delimiter=',',header=None))
    feature_names += [f'{model}_0CO', f'{model}_1EL', f'{model}_2GR', f'{model}_3HI', f'{model}_4MI', f'{model}_5PH']
    
trn = np.hstack(trn)
tst = np.hstack(tst)
feature_names
# Out:
# ['lrcvPolyfeature_0CO',
#  'lrcvPolyfeature_1EL',
#  'lrcvPolyfeature_2GR',
#  'lrcvPolyfeature_3HI',
#  'lrcvPolyfeature_4MI',
#  'lrcvPolyfeature_5PH',
#  'rfcvFeature_0CO',
#  'rfcvFeature_1EL',
#  'rfcvFeature_2GR',
#  'rfcvFeature_3HI',
#  'rfcvFeature_4MI',
#  'rfcvFeature_5PH',
#  'lgbmcvFeature_0CO',
#  'lgbmcvFeature_1EL',
#  'lgbmcvFeature_2GR',
#  'lgbmcvFeature_3HI',
#  'lgbmcvFeature_4MI',
#  'lgbmcvFeature_5PH']

# %%
df = pd.read_csv(trn_file, header=None)
y = pd.DataFrame(df[0].values.flatten())
y.shape
# Out:
# (4280, 1)

# %%
seed=150
kfold=10

# %% [markdown]
# ## Stratified K-Fold Cross Validation
# *Stratified N-Fold CV: N-Fold CV에서 각각의 폴드에서 종속변수의 분포가 동일하도록 폴드를 나누는 방식.
# 현재 사용하는 데이터처럼 분류학습에서 종속변수의 범주의 분포가 균일하지 않을 때 사용된다.

# %%
cv = StratifiedKFold(n_splits=kfold, shuffle=True, random_state=seed)

# %% [markdown]
# ### [범주형 > 수치형 변환_종속변수]

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

label_str=y
label_int=le.fit_transform(label_str).astype('int')
y
label_int
# Out:
# array([3, 5, 2, ..., 1, 5, 1])

# %% [markdown]
# ## LightGBM 모델 학습

# %%
p_val = np.zeros((trn.shape[0], 6))
p_tst = np.zeros((tst.shape[0], 6))
for i, (i_trn, i_val) in enumerate(cv.split(trn, y), 1):
    print(f'training model for CV #{i}')
    clf = lgb.LGBMClassifier(objective='multiclass',
                             #boosting_type='dart', 
                             #n_estimators=300,
                             #learning_rate=0.1,
                             #num_leaves=64,
                            # min_child_samples=10,   
                            # subsample=.5,                       
                            # subsample_freq=1,    
                             #colsample_bytree= 0.8,
                             random_state=seed,
                             n_jobs=-1)
    clf.fit(trn[i_trn], label_int[i_trn],
            eval_set=[(trn[i_val], label_int[i_val])],
            eval_metric='multiclass',
            early_stopping_rounds=15)
    
    p_val[i_val, :] = clf.predict_proba(trn[i_val])
    p_tst += clf.predict_proba(tst) / kfold
print(f'{accuracy_score(label_int, np.argmax(p_val, axis=1)) * 100:.4f}%')
# Out:
# training model for CV #1
# [1]	valid_0's multi_logloss: 1.33176
# Training until validation scores don't improve for 15 rounds
# [2]	valid_0's multi_logloss: 1.09859
# [3]	valid_0's multi_logloss: 0.930877
# [4]	valid_0's multi_logloss: 0.805459
# [5]	valid_0's multi_logloss: 0.704994
# [6]	valid_0's multi_logloss: 0.626196
# [7]	valid_0's multi_logloss: 0.561101
# [8]	valid_0's multi_logloss: 0.507383
# [9]	valid_0's multi_logloss: 0.464569
# [10]	valid_0's multi_logloss: 0.426836
# [11]	valid_0's multi_logloss: 0.398122
# [12]	valid_0's multi_logloss: 0.370911
# [13]	valid_0's multi_logloss: 0.351142
# [14]	valid_0's multi_logloss: 0.334921
# [15]	valid_0's multi_logloss: 0.320919
# [16]	valid_0's multi_logloss: 0.309336
# [17]	valid_0's multi_logloss: 0.29834
# [18]	valid_0's multi_logloss: 0.288933
# [19]	valid_0's multi_logloss: 0.282313
# [20]	valid_0's multi_logloss: 0.277816
# [21]	valid_0's multi_logloss: 0.272058
# [22]	valid_0's multi_logloss: 0.267682
# [23]	valid_0's multi_logloss: 0.26463
# [24]	valid_0's multi_logloss: 0.261894
# [25]	valid_0's multi_logloss: 0.25896
# [26]	valid_0's multi_logloss: 0.258375
# [27]	valid_0's multi_logloss: 0.258265
# [28]	valid_0's multi_logloss: 0.258589
# [29]	valid_0's multi_logloss: 0.258956
# [30]	valid_0's multi_logloss: 0.260293
# [31]	valid_0's multi_logloss: 0.260485
# [32]	valid_0's multi_logloss: 0.26207
# [33]	valid_0's multi_logloss: 0.262671
# [34]	valid_0's multi_logloss: 0.264719
# [35]	valid_0's multi_logloss: 0.265842
# [36]	valid_0's multi_logloss: 0.265484
# [37]	valid_0's multi_logloss: 0.266558
# [38]	valid_0's multi_logloss: 0.268256
# [39]	valid_0's multi_logloss: 0.26932
# [40]	valid_0's multi_logloss: 0.270904
# [41]	valid_0's multi_logloss: 0.272122
# [42]	valid_0's multi_logloss: 0.274724
# Early stopping, best iteration is:
# [27]	valid_0's multi_logloss: 0.258265
# training model for CV #2
# [1]	valid_0's multi_logloss: 1.35437
# Training until validation scores don't improve for 15 rounds
# [2]	valid_0's multi_logloss: 1
# [26]	valid_0's multi_logloss: 0.221568
# [27]	valid_0's multi_logloss: 0.220593
# [28]	valid_0's multi_logloss: 0.219919
# [29]	valid_0's multi_logloss: 0.220286
# [30]	valid_0's multi_logloss: 0.22126
# [31]	valid_0's multi_logloss: 0.221679
# [32]	valid_0's multi_logloss: 0.222598
# [33]	valid_0's multi_logloss: 0.22424
# [34]	valid_0's multi_logloss: 0.225487
# [35]	valid_0's multi_logloss: 0.226115
# [36]	valid_0's multi_logloss: 0.227149
# [37]	valid_0's multi_logloss: 0.228914
# [38]	valid_0's multi_logloss: 0.229624
# [39]	valid_0's multi_logloss: 0.230542
# [40]	valid_0's multi_logloss: 0.232028
# [41]	valid_0's multi_logloss: 0.233307
# [42]	valid_0's multi_logloss: 0.235028
# [43]	valid_0's multi_logloss: 0.237335
# Early stopping, best iteration is:
# [28]	valid_0's multi_logloss: 0.219919
# training model for CV #4
# [1]	valid_0's multi_logloss: 1.33543
# Training until validation scores don't improve for 15 rounds
# [2]	valid_0's multi_logloss: 1.10721
# [3]	valid_0's multi_logloss: 0.939544
# [4]	valid_0's multi_logloss: 0.815473
# [5]	valid_0's multi_logloss: 0.716252
# [6]	valid_0's multi_logloss: 0.636077
# [7]	valid_0's multi_logloss: 0.571855
# [8]	valid_0's multi_logloss: 0.519304
# [9]	valid_0's multi_logloss: 0.475551
# [10]	valid_0's multi_logloss: 0.440361
# [11]	valid_0's multi_logloss: 0.410648
# [12]	valid_0's multi_logloss: 0.386323
# [13]	valid_0's multi_logloss: 0.365268
# [14]	valid_0's multi_logloss: 0.34859
# [15]	valid_0's multi_logloss: 0.332906
# [16]	valid_0's multi_logloss: 0.319976
# [17]	valid_0's multi_logloss: 0.308181
# [18]	valid_0's multi_logloss: 0.29842
# [19]	valid_0's multi_logloss: 0.289713
# [20]	valid_0's multi_logloss: 0.283788
# [21]	valid_0's multi_logloss: 0.28038
# [22]	valid_0's multi_logloss: 0.277011
# [23]	valid_0's multi_logloss: 0.272326
# [24]	valid_0's multi_logloss: 0.269215
# [25]	valid_0's multi_logloss: 0.266733
# [26]	valid_0's multi_logloss: 0.26389
# [27]	valid_0's multi_logloss: 0.262461
# [28]	valid_0's multi_logloss: 0.260776
# [29]	valid_0's multi_logloss: 0.261734
# [30]	valid_0's multi_logloss: 0.262542
# [31]	valid_0's multi_logloss: 0.262668
# [32]	valid_0's multi_logloss: 0.263121
# [33]	valid_0's multi_logloss: 0.262017
# [34]	valid_0's multi_logloss: 0.263248
# [35]	valid_0's multi_logloss: 0.263242
# [36]	valid_0's multi_logloss: 0.263462
# [37]	valid_0's multi_logloss: 0.264748
# [38]	valid_0's multi_logloss: 0.26723
# [39]	valid_0's multi_logloss: 0.267665
# [40]	valid_0's multi_logloss: 0.266285
# [41]	valid_0's multi_logloss: 0.266967
# [42]	valid_0's multi_logloss: 0.267574
# [43]	valid_0's multi_logloss: 0.266166
# Early stopping, best iteration is:
# [28]	valid_0's multi_logloss: 0.260776
# training model for CV #5
# [1]	valid_0's multi_logloss: 1.3319
# Training until validation scores don't improve for 15 rounds
# [2]	valid_0's multi_logloss: 1
# [27]	valid_0's multi_logloss: 0.252432
# [28]	valid_0's multi_logloss: 0.250661
# [29]	valid_0's multi_logloss: 0.249708
# [30]	valid_0's multi_logloss: 0.249078
# [31]	valid_0's multi_logloss: 0.24895
# [32]	valid_0's multi_logloss: 0.24854
# [33]	valid_0's multi_logloss: 0.248388
# [34]	valid_0's multi_logloss: 0.248649
# [35]	valid_0's multi_logloss: 0.249588
# [36]	valid_0's multi_logloss: 0.249978
# [37]	valid_0's multi_logloss: 0.2501
# [38]	valid_0's multi_logloss: 0.250093
# [39]	valid_0's multi_logloss: 0.250131
# [40]	valid_0's multi_logloss: 0.251608
# [41]	valid_0's multi_logloss: 0.251075
# [42]	valid_0's multi_logloss: 0.251666
# [43]	valid_0's multi_logloss: 0.25249
# [44]	valid_0's multi_logloss: 0.25523
# [45]	valid_0's multi_logloss: 0.256459
# [46]	valid_0's multi_logloss: 0.257352
# [47]	valid_0's multi_logloss: 0.258865
# [48]	valid_0's multi_logloss: 0.258979
# Early stopping, best iteration is:
# [33]	valid_0's multi_logloss: 0.248388
# training model for CV #7
# [1]	valid_0's multi_logloss: 1.32126
# Training until validation scores don't improve for 15 rounds
# [2]	valid_0's multi_logloss: 1.08063
# [3]	valid_0's multi_logloss: 0.907665
# [4]	valid_0's multi_logloss: 0.777033
# [5]	valid_0's multi_logloss: 0.673768
# [6]	valid_0's multi_logloss: 0.589357
# [7]	valid_0's multi_logloss: 0.520793
# [8]	valid_0's multi_logloss: 0.465705
# [9]	valid_0's multi_logloss: 0.419857
# [10]	valid_0's multi_logloss: 0.381811
# [11]	valid_0's multi_logloss: 0.350827
# [12]	valid_0's multi_logloss: 0.325688
# [13]	valid_0's multi_logloss: 0.304173
# [14]	valid_0's multi_logloss: 0.285822
# [15]	valid_0's multi_logloss: 0.269296
# [16]	valid_0's multi_logloss: 0.254966
# [17]	valid_0's multi_logloss: 0.242054
# [18]	valid_0's multi_logloss: 0.233787
# [19]	valid_0's multi_logloss: 0.22739
# [20]	valid_0's multi_logloss: 0.221186
# [21]	valid_0's multi_logloss: 0.215414
# [22]	valid_0's multi_logloss: 0.209965
# [23]	valid_0's multi_logloss: 0.206094
# [24]	valid_0's multi_logloss: 0.204723
# [25]	valid_0's multi_logloss: 0.202302
# [26]	valid_0's multi_logloss: 0.201076
# [27]	valid_0's multi_logloss: 0.200037
# [28]	valid_0's multi_logloss: 0.199221
# [29]	valid_0's multi_logloss: 0.198964
# [30]	valid_0's multi_logloss: 0.198043
# [31]	valid_0's multi_logloss: 0.197229
# [32]	valid_0's multi_logloss: 0.197555
# [33]	valid_0's multi_logloss: 0.198388
# [34]	valid_0's multi_logloss: 0.198822
# [35]	valid_0's multi_logloss: 0.198901
# [36]	valid_0's multi_logloss: 0.199055
# [37]	valid_0's multi_logloss: 0.199932
# [38]	valid_0's multi_logloss: 0.20066
# [39]	valid_0's multi_logloss: 0.202335
# [40]	valid_0's multi_logloss: 0.203259
# [41]	valid_0's multi_logloss: 0.204519
# [42]	valid_0's multi_logloss: 0.20548
# [43]	valid_0's multi_logloss: 0.206287
# [44]	valid_0's multi_logloss: 0.206851
# [45]	valid_0's multi_logloss: 0.207939
# [46]	valid_0's multi_logloss: 0.209271
# Early stopping, best iteration is:
# [31]	valid_0's multi_logloss: 0.197229
# training model for CV #8
# [1]	valid_0's multi_logloss: 1.32753
# Training until validation scores don't improve for 15 rounds
# [2]	valid_0's multi_logloss: 1
# [30]	valid_0's multi_logloss: 0.32255
# [31]	valid_0's multi_logloss: 0.324752
# [32]	valid_0's multi_logloss: 0.325234
# [33]	valid_0's multi_logloss: 0.326746
# [34]	valid_0's multi_logloss: 0.329227
# [35]	valid_0's multi_logloss: 0.331163
# [36]	valid_0's multi_logloss: 0.334862
# [37]	valid_0's multi_logloss: 0.338862
# [38]	valid_0's multi_logloss: 0.341939
# [39]	valid_0's multi_logloss: 0.345901
# [40]	valid_0's multi_logloss: 0.347941
# [41]	valid_0's multi_logloss: 0.352826
# Early stopping, best iteration is:
# [26]	valid_0's multi_logloss: 0.317664
# 90.9813%

# %%
scores = cross_val_score(clf, trn,y, cv=10) # model, train, target, cross validation
print('cross-val-score.mean \n{:.4f}%'.format(scores.mean()*100))
# Out:
# cross-val-score.mean
# 91.2850%

# %%
#3000 256 003 10 08 06 42 15번  >>90
p_val = np.zeros((trn.shape[0], 6))
p_tst = np.zeros((tst.shape[0], 6))
for i, (i_trn, i_val) in enumerate(cv.split(trn, y), 1):
    print(f'training model for CV #{i}')
    clf = lgb.LGBMClassifier(objective='multiclass',
                             n_estimators=1000,
                             num_leaves=64,
                             learning_rate=0.1,
                             min_child_samples=10,
                             subsample=.5,
                             subsample_freq=1,
                             colsample_bytree=.8,
                             random_state=42,
                             n_jobs=-1)
    clf.fit(trn[i_trn], label_int[i_trn],
            eval_set=[(trn[i_val], label_int[i_val])],
            eval_metric='multiclass',
            early_stopping_rounds=15)
    
    p_val[i_val, :] = clf.predict_proba(trn[i_val])
    p_tst += clf.predict_proba(tst) / kfold
# Out:
# training model for CV #1
# [1]	valid_0's multi_logloss: 1.3341
# Training until validation scores don't improve for 15 rounds
# [2]	valid_0's multi_logloss: 1.10426
# [3]	valid_0's multi_logloss: 0.934106
# [4]	valid_0's multi_logloss: 0.809816
# [5]	valid_0's multi_logloss: 0.712545
# [6]	valid_0's multi_logloss: 0.633755
# [7]	valid_0's multi_logloss: 0.571505
# [8]	valid_0's multi_logloss: 0.51755
# [9]	valid_0's multi_logloss: 0.476104
# [10]	valid_0's multi_logloss: 0.441274
# [11]	valid_0's multi_logloss: 0.407754
# [12]	valid_0's multi_logloss: 0.383484
# [13]	valid_0's multi_logloss: 0.361799
# [14]	valid_0's multi_logloss: 0.345926
# [15]	valid_0's multi_logloss: 0.33098
# [16]	valid_0's multi_logloss: 0.318071
# [17]	valid_0's multi_logloss: 0.304949
# [18]	valid_0's multi_logloss: 0.297817
# [19]	valid_0's multi_logloss: 0.291833
# [20]	valid_0's multi_logloss: 0.285674
# [21]	valid_0's multi_logloss: 0.282317
# [22]	valid_0's multi_logloss: 0.280365
# [23]	valid_0's multi_logloss: 0.278853
# [24]	valid_0's multi_logloss: 0.278035
# [25]	valid_0's multi_logloss: 0.276348
# [26]	valid_0's multi_logloss: 0.276857
# [27]	valid_0's multi_logloss: 0.27895
# [28]	valid_0's multi_logloss: 0.278009
# [29]	valid_0's multi_logloss: 0.277697
# [30]	valid_0's multi_logloss: 0.276136
# [31]	valid_0's multi_logloss: 0.275311
# [32]	valid_0's multi_logloss: 0.274656
# [32]	valid_0's multi_logloss: 0.269273
# [33]	valid_0's multi_logloss: 0.269086
# [34]	valid_0's multi_logloss: 0.26661
# [35]	valid_0's multi_logloss: 0.270084
# [36]	valid_0's multi_logloss: 0.271277
# [37]	valid_0's multi_logloss: 0.274798
# [38]	valid_0's multi_logloss: 0.277859
# [39]	valid_0's multi_logloss: 0.279651
# [40]	valid_0's multi_logloss: 0.282394
# [41]	valid_0's multi_logloss: 0.284593
# [42]	valid_0's multi_logloss: 0.287687
# [43]	valid_0's multi_logloss: 0.291063
# [44]	valid_0's multi_logloss: 0.293318
# [45]	valid_0's multi_logloss: 0.29434
# [46]	valid_0's multi_logloss: 0.297063
# [47]	valid_0's multi_logloss: 0.300398
# [48]	valid_0's multi_logloss: 0.30212
# [49]	valid_0's multi_logloss: 0.30253
# Early stopping, best iteration is:
# [34]	valid_0's multi_logloss: 0.26661
# training model for CV #5
# [1]	valid_0's multi_logloss: 1.33381
# Training until validation scores don't improve for 15 rounds
# [2]	valid_0's multi_logloss: 1.10045
# [3]	valid_0's multi_logloss: 0.932364
# [4]	valid_0's multi_logloss: 0.807729
# [5]	valid_0's multi_logloss: 0.707191
# [6]	valid_0's multi_logloss: 0.626544
# [7]	valid_0's multi_logloss: 0.564179
# [8]	valid_0's multi_logloss: 0.512405
# [9]	valid_0's multi_logloss: 0.46991
# [10]	valid_0's multi_logloss: 0.433652
# [11]	valid_0's multi_logloss: 0.405589
# [12]	valid_0's multi_logloss: 0.382489
# [13]	valid_0's multi_logloss: 0.365314
# [14]	valid_0's multi_logloss: 0.347386
# [15]	valid_0's multi_logloss: 0.334456
# [16]	valid_0's multi_logloss: 0.319675
# [17]	valid_0's multi_logloss: 0.309727
# [18]	valid_0's multi_logloss: 0.30098
# [19]	valid_0's multi_logloss: 0.295542
# [20]	valid_0's multi_logloss: 0.289911
# [21]	valid_0's multi_logloss: 0.285989
# [22]	valid_0's multi_logloss: 0.28275
# [23]	valid_0's multi_logloss: 0.280516
# [24]	valid_0's multi_logloss: 0.278236
# [25]	valid_0's multi_logloss: 0.278732
# [26]	valid_0's multi_logloss: 0.275563
# [27]	valid_0's multi_logloss: 0.275283
# [28]	valid_0's multi_logloss: 0.277227
# [29]	valid_0's multi_logloss: 0.27825
# [30]	valid_0's multi_logloss: 0.278791
# [31]	valid_0's multi_logloss: 0.27811
# [32]	valid_0's multi_logloss: 0.282011
# [33]	valid_0's multi_logloss: 0.283128
# [34]	valid_0's multi_logloss: 0.284858
# [35]	valid_0's multi_logloss: 0.285661
# [36]	valid_0's multi_logloss: 0.287742
# [37]	valid_0's multi_logloss: 0.288977
# [38]	valid_0's multi_logloss: 0.290659
# [39]	valid_0's multi_logloss: 0.291762
# [40]	valid_0's multi_logloss: 0.292242
# [41]	valid_0's multi_logloss: 0.295348
# [42]	valid_0's multi_logloss: 0.300593
# Early stopping, best iteration is:
# [27]	valid_0's multi_logloss: 0.275283
# training model for CV #6
# [1]	valid_0's multi_logloss: 1.3238
# Training until validation scores don't improve for 15 rounds
# [2]	valid_0's multi_logloss: 1
# [22]	valid_0's multi_logloss: 0.322123
# [23]	valid_0's multi_logloss: 0.321168
# [24]	valid_0's multi_logloss: 0.322885
# [25]	valid_0's multi_logloss: 0.323056
# [26]	valid_0's multi_logloss: 0.323863
# [27]	valid_0's multi_logloss: 0.320635
# [28]	valid_0's multi_logloss: 0.322236
# [29]	valid_0's multi_logloss: 0.32107
# [30]	valid_0's multi_logloss: 0.323766
# [31]	valid_0's multi_logloss: 0.326992
# [32]	valid_0's multi_logloss: 0.325734
# [33]	valid_0's multi_logloss: 0.326657
# [34]	valid_0's multi_logloss: 0.327678
# [35]	valid_0's multi_logloss: 0.331434
# [36]	valid_0's multi_logloss: 0.334972
# [37]	valid_0's multi_logloss: 0.334962
# [38]	valid_0's multi_logloss: 0.337378
# [39]	valid_0's multi_logloss: 0.34074
# [40]	valid_0's multi_logloss: 0.343423
# [41]	valid_0's multi_logloss: 0.344944
# [42]	valid_0's multi_logloss: 0.34865
# Early stopping, best iteration is:
# [27]	valid_0's multi_logloss: 0.320635

# %%
print(f'{accuracy_score(label_int, np.argmax(p_val, axis=1)) * 100:.4f}%') #90.9112 강사 베이스 91.4486
# Out:
# 91.1682%

# %% [markdown]
# ## Simple way Cross Validation

# %%
scores = cross_val_score(clf, trn,y, cv=10) # model, train, target, cross validation
print('cross-val-score \n{}'.format(scores))
print('cross-val-score.mean \n{:.3f}'.format(scores.mean()*100))
# Out:
# cross-val-score
# [0.9228972  0.93224299 0.9135514  0.9135514  0.91121495 0.91121495
#  0.88317757 0.9228972  0.9228972  0.90186916]
# cross-val-score.mean
# 91.355

# %%
print(p_val.shape, p_tst.shape)
# Out:
# (4280, 6) (1833, 6)

# %% [markdown]
# #### [stacking 사용을 위해 p_val,p_tst 저장]

# %%
val_dir = Path('C:\\Users\\USER\\Desktop\\Dataset\\val')
tst_dir = Path('C:\\Users\\USER\\Desktop\\Dataset\\tst')
name = 'lgbmStacking1'
model_name = f'{name}'
p_val_file = val_dir / f'{name}.val.csv'
p_tst_file = tst_dir / f'{name}.tst.csv'

# %%
np.savetxt(p_val_file, p_val, fmt='%.6f', delimiter=',')
np.savetxt(p_tst_file, p_tst, fmt='%.6f', delimiter=',')

# %% [markdown]
# ## 피처 중요도 시각화
# 여러 모델 시각화 대신 각 모델에서 손실 감소에 기여한 피처들의 중요도를 보기 위한 과정

# %%
imp = pd.DataFrame({'feature': feature_names, 'importance': clf.feature_importances_})
imp = imp.sort_values('importance').set_index('feature')
imp.plot(kind='barh')

# %% [markdown]
# ### [수치형 > 범주형 변환_종속변수]

# %%
pt=np.zeros(shape=(1833,))
pt = pt.astype(np.int64)
for x in range(0,1833):
    pt[x] = np.argmax(p_tst[x,:])
target=le.inverse_transform(pt)
target
# Out:
# array(['HI', 'EL', 'HI', ..., 'PH', 'PH', 'CO'], dtype=object)

# %% [markdown]
# ## 제출 파일 생성

# %%
sub = pd.read_csv(sample_file)
sub['class'] = target
sub.to_csv('C:\\Users\\USER\\Desktop\\Dataset\\sub\\lgbmstacking-sub.csv',index=False,header=False)
